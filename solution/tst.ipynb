# %% [markdown]
# # Przykład wykorzystania algorytmu Symulowanego Wyżarzania:

# %% [markdown]
# Importowanie bibliotek

# %%
from typing import Tuple, Union
from numpy.random import randint
from numpy import exp

import matplotlib.pyplot as plt

from tap_lib.SimulatedAnnealing import generate_sa_algorithm, plot_scope, ScopeParams

# %% [markdown]
# __Definicja funkcji kosztu__
# $$
# f(x, y) = x^2 + y^2
# $$

# %% [markdown]
# Definiowanie wszystkich potrzebnych funkcji:

# %%
def cost_fun(vec):
    (x, y) = vec

    return x**2 + y**2

def sol_gen_fun(vec):
    (x, y) = vec
    step = 0.01

    if randint(2) == 0:
        if randint(2) == 0:
            x += step
        else:
            x -= step
    else:
        if randint(2) == 0:
            y += step
        else:
            y -= step

    if x < -5:
        x = -5
    if x > 5:
        x = 5
    if y < -5:
        y = -5
    if y > 5:
        y = 5

    return x, y

def colling_fun(_, k):
    temp = (1 - (k + 1) / max_iter) * start_temp

    if temp <= 10**(-9):
        return 0.0001
    return temp

def prob_fun(delta_en, temp):
    if delta_en < 0:
        return 1
    return exp(-delta_en / (1.380649 * temp))

# %% [markdown]
# Wygenerowanie algorytmu

# %%
solution_type = Tuple[Union[int, float], Union[int, float]]
sim_an = generate_sa_algorithm(solution_type)

# %% [markdown]
# Wykonanie algorytmu i wizualizacja danych

# %%
max_iter = 1000000
start_temp = 0.1
init_sol_tup = (2, -2)

sol, scope = sim_an(cost=cost_fun,
                    init_sol=init_sol_tup,
                    sol_gen=sol_gen_fun,
                    init_temp=start_temp,
                    cool=colling_fun,
                    probability=prob_fun,
                    max_iterations=max_iter)

# %% [markdown]
# Analiza wyników

# %%
print(f'Solution = {sol}')

plot_scope(scope)

x_vec = [tup[0] for tup in scope[ScopeParams.solution]]
y_vec = [tup[1] for tup in scope[ScopeParams.solution]]

plt.plot(x_vec, y_vec, 'b.', markersize=1, label='Visited')
plt.plot(0, 0, 'g.', markersize=10, label='Analytical Solution')
plt.plot(sol[0], sol[1], 'r.', markersize=10, label='Solution')
plt.title('solutions')
plt.legend()
plt.show()
# Out:
# Solution = (4.430000000000012, -2.4800000000000537)

# %% [markdown]
# __Modyfikacja funkcji chłodzenia__

# %%
def colling_fun(_, k):
    temp = start_temp * exp(-k / max_iter * 10)

    return temp

# %%
sol, scope = sim_an(cost=cost_fun,
                    init_sol=init_sol_tup,
                    sol_gen=sol_gen_fun,
                    init_temp=start_temp,
                    cool=colling_fun,
                    probability=prob_fun,
                    max_iterations=max_iter)

# %%
print(f'Solution = {sol}')

plot_scope(scope)

x_vec = [tup[0] for tup in scope[ScopeParams.solution]]
y_vec = [tup[1] for tup in scope[ScopeParams.solution]]

plt.plot(x_vec, y_vec, 'b.', markersize=1, label='Visited')
plt.plot(0, 0, 'g.', markersize=10, label='Analytical Solution')
plt.plot(sol[0], sol[1], 'r.', markersize=10, label='Solution')
plt.title('solutions')
plt.legend()
plt.show()
# Out:
# Solution = (-1.4299999999999384, 1.980000000000064)
